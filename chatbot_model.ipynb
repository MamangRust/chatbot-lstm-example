# %%
import numpy as np
import pandas as pd

import json

# %%
with open("intens.json", 'r') as f:
    data = json.load(f)


df = pd.DataFrame(data['intents'])

df
# Out:
#                   tag                                           patterns  \
# 0            greeting  [Hi, Hey, Is anyone there?, Hi there, Hello, H...
# 1         school_info  [Tell me about the school, What makes the scho...
# 2           admission  [How can I apply for admission?, Admission pro...
# 3     extracurricular  [What extracurricular activities are available...
# 4              events  [Tell me about upcoming events, School events,...
# 5    random_command_1  [What's the cafeteria menu for today?, Tell me...
# 6    random_command_2  [How can I contact the school administration?,...
# 7    random_command_3  [Tell me about the school library, Library ser...
# 8    random_command_4  [What sports facilities does the school have?,...
# 9    random_command_5  [Are there any scholarship opportunities?, Sch...
# 10   random_command_6  [Tell me about the technology in classrooms, C...
# 11   random_command_7  [Can I tour the school facilities?, School tou...
# 12   random_command_8  [How is the school involved in the community?,...
# 13   random_command_9  [Tell me about the school's educational philos...
# 14  random_command_10  [How is the school addressing diversity and in...
#
#                                             responses
# 0   [Hello there. How can I help you?, Hi there. W...
# 1   [Our school is known for its dedicated teacher...
# 2   [To apply for admission, you can visit our sch...
# 3   [We offer a wide range of extracurricular acti...
# 4   [Stay tuned for our upcoming events! We regula...
# 5   [Our cafeteria serves a variety of healthy and...
# 6   [You can contact the school administration by ...
# 7   [Our school library provides a quiet and comfo...
# 8   [Our school boasts state-of-the-art sports fac...
# 9   [Yes, we offer scholarship opportunities to de...
# 10  [Our classrooms are equipped with modern techn...
# 11  [Certainly! We encourage prospective students ...
# 12  [We actively engage with the local community t...
# 13  [Our school follows a student-centered educati...
# 14  [We are committed to creating an inclusive and...

# %%
dic = {"tag":[], "patterns":[], "responses":[]}  # Membuat dictionary kosong untuk menyimpan data yang akan diubah ke DataFrame
for i in range(len(df)):
    ptrns = df[df.index == i]['patterns'].values[0]  # Mengambil pola (patterns) dari DataFrame
    rspns = df[df.index == i]['responses'].values[0]  # Mengambil respons dari DataFrame
    tag = df[df.index == i]['tag'].values[0]  # Mengambil tag dari DataFrame
    for j in range(len(ptrns)):
        dic['tag'].append(tag)  # Menambahkan tag ke dalam dictionary
        dic['patterns'].append(ptrns[j])  # Menambahkan pola ke dalam dictionary
        dic['responses'].append(rspns)  # Menambahkan respons ke dalam dictionary

df = pd.DataFrame.from_dict(dic)  # Membuat DataFrame baru dari dictionary
pd.set_option("display.max_rows", None)  # Menampilkan semua baris DataFrame ketika ditampilkan
df  # Menampilkan DataFrame
# Out:
#                   tag                                           patterns  \
# 0            greeting                                                 Hi
# 1            greeting                                                Hey
# 2            greeting                                   Is anyone there?
# 3            greeting                                           Hi there
# 4            greeting                                              Hello
# 5            greeting                                          Hey there
# 6            greeting                                              Howdy
# 7            greeting                                               Hola
# 8            greeting                                            Bonjour
# 9            greeting                                         Konnichiwa
# 10           greeting                                          Guten tag
# 11           greeting                                                Ola
# 12        school_info                           Tell me about the school
# 13        school_info                      What makes the school unique?
# 14        school_info                                    School features
# 15        school_info                  Give me an overview of the school
# 16          admission                     How can I apply for admission?
# 17          admission                                  Admission process
# 18          admission                              Application procedure
# 19    extracurricular     What extracurricular activities are available?
# 20    extracurricular                               Clubs and activities
# 21    extracurricular                            Extracurricular options
# 22             events                      Tell me about upcoming events
# 23             events                                      School events
# 24             events                         Any events happening soon?
# 25   random_command_1               What's the cafeteria menu for today?
# 26   random_command_1                    Tell me about the lunch options
# 27   random_command_1                                Cafeteria offerings
# 28   random_command_2       How can I contact the school administration?
# 29   random_command_2                                    Contact details
# 30   random_command_2                              School office contact
# 31   random_command_3                   Tell me about the school library
# 32   random_command_3                                   Library services
# 33   random_command_3                                    Available books
# 34   random_command_4       What sports facilities does the school have?
# 35   random_command_4                                   Sports amenities
# 36   random_command_4                                Athletic facilities
# 37   random_command_5           Are there any scholarship opportunities?
# 38   random_command_5                               Scholarship programs
# 39   random_command_5                                      Financial aid
# 40   random_command_6         Tell me about the technology in classrooms
# 41   random_command_6                               Classroom technology
# 42   random_command_6                               Interactive learning
# 43   random_command_7                  Can I tour the school facilities?
# 44   random_command_7                                       School tours
# 45   random_command_7                                   Visit the campus
# 46   random_command_8       How is the school involved in the community?
# 47   random_command_8                               Community engagement
# 48   random_command_8                                  Outreach programs
# 49   random_command_9  Tell me about the school's educational philosophy
# 50   random_command_9                                  Teaching approach
# 51   random_command_9                            Philosophy of education
# 52  random_command_10  How is the school addressing diversity and inc...
# 53  random_command_10                              Diversity initiatives
# 54  random_command_10                              Inclusive environment
#
#                                             responses
# 0   [Hello there. How can I help you?, Hi there. W...
# 1   [Hello there. How can I help you?, Hi there. W...
# 2   [Hello there. How can I help you?, Hi there. W...
# 3   [Hello there. How can I help you?, Hi there. W...
# 4   [Hello there. How can I help you?, Hi there. W...
# 5   [Hello there. How can I help you?, Hi there. W...
# 6   [Hello there. How can I help you?, Hi there. W...
# 7   [Hello there. How can I help you?, Hi there. W...
# 8   [Hello there. How can I help you?, Hi there. W...
# 9   [Hello there. How can I help you?, Hi there. W...
# 10  [Hello there. How can I help you?, Hi there. W...
# 11  [Hello there. How can I help you?, Hi there. W...
# 12  [Our school is known for its dedicated teacher...
# 13  [Our school is known for its dedicated teacher...
# 14  [Our school is known for its dedicated teacher...
# 15  [Our school is known for its dedicated teacher...
# 16  [To apply for admission, you can visit our sch...
# 17  [To apply for admission, you can visit our sch...
# 18  [To apply for admission, you can visit our sch...
# 19  [We offer a wide range of extracurricular acti...
# 20  [We offer a wide range of extracurricular acti...
# 21  [We offer a wide range of extracurricular acti...
# 22  [Stay tuned for our upcoming events! We regula...
# 23  [Stay tuned for our upcoming events! We regula...
# 24  [Stay tuned for our upcoming events! We regula...
# 25  [Our cafeteria serves a variety of healthy and...
# 26  [Our cafeteria serves a variety of healthy and...
# 27  [Our cafeteria serves a variety of healthy and...
# 28  [You can contact the school administration by ...
# 29  [You can contact the school administration by ...
# 30  [You can contact the school administration by ...
# 31  [Our school library provides a quiet and comfo...
# 32  [Our school library provides a quiet and comfo...
# 33  [Our school library provides a quiet and comfo...
# 34  [Our school boasts state-of-the-art sports fac...
# 35  [Our school boasts state-of-the-art sports fac...
# 36  [Our school boasts state-of-the-art sports fac...
# 37  [Yes, we offer scholarship opportunities to de...
# 38  [Yes, we offer scholarship opportunities to de...
# 39  [Yes, we offer scholarship opportunities to de...
# 40  [Our classrooms are equipped with modern techn...
# 41  [Our classrooms are equipped with modern techn...
# 42  [Our classrooms are equipped with modern techn...
# 43  [Certainly! We encourage prospective students ...
# 44  [Certainly! We encourage prospective students ...
# 45  [Certainly! We encourage prospective students ...
# 46  [We actively engage with the local community t...
# 47  [We actively engage with the local community t...
# 48  [We actively engage with the local community t...
# 49  [Our school follows a student-centered educati...
# 50  [Our school follows a student-centered educati...
# 51  [Our school follows a student-centered educati...
# 52  [We are committed to creating an inclusive and...
# 53  [We are committed to creating an inclusive and...
# 54  [We are committed to creating an inclusive and...

# %%
df.to_excel('chatbot.xlsx', index=False)

# %%
df['tag'].unique()
# Out:
# array(['greeting', 'school_info', 'admission', 'extracurricular',
#        'events', 'random_command_1', 'random_command_2',
#        'random_command_3', 'random_command_4', 'random_command_5',
#        'random_command_6', 'random_command_7', 'random_command_8',
#        'random_command_9', 'random_command_10'], dtype=object)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(lower=True, split=' ')
tokenizer.fit_on_texts(df['patterns'])
tokenizer.get_config()
# Out:
# {'num_words': None,
#  'filters': '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
#  'lower': True,
#  'split': ' ',
#  'char_level': False,
#  'oov_token': None,
#  'document_count': 55,
#  'word_counts': '{"hi": 2, "hey": 2, "is": 3, "anyone": 1, "there": 4, "hello": 1, "howdy": 1, "hola": 1, "bonjour": 1, "konnichiwa": 1, "guten": 1, "tag": 1, "ola": 1, "tell": 6, "me": 7, "about": 6, "the": 15, "school": 13, "what": 3, "makes": 1, "unique": 1, "features": 1, "give": 1, "an": 1, "overview": 1, "of": 2, "how": 4, "can": 3, "i": 3, "apply": 1, "for": 2, "admission": 2, "process": 1, "application": 1, "procedure": 1, "extracurricular": 2, "activities": 2, "are": 2, "available": 2, "clubs": 1, "and": 2, "options": 2, "upcoming": 1, "events": 3, "any": 2, "happening": 1, "soon": 1, "what\'s": 1, "cafeteria": 2, "menu": 1, "today": 1, "lunch": 1, "offerings": 1, "contact": 3, "administration": 1, "details": 1, "office": 1, "library": 2, "services": 1, "books": 1, "sports": 2, "facilities": 3, "does": 1, "have": 1, "amenities": 1, "athletic": 1, "scholarship": 2, "opportunities": 1, "programs": 2, "financial": 1, "aid": 1, "technology": 2, "in": 2, "classrooms": 1, "classroom": 1, "interactive": 1, "learning": 1, "tour": 1, "tours": 1, "visit": 1, "campus": 1, "involved": 1, "community": 2, "engagement": 1, "outreach": 1, "school\'s": 1, "educational": 1, "philosophy": 2, "teaching": 1, "approach": 1, "education": 1, "addressing": 1, "diversity": 2, "inclusion": 1, "initiatives": 1, "inclusive": 1, "environment": 1}',
#  'word_docs': '{"hi": 2, "hey": 2, "there": 4, "is": 3, "anyone": 1, "hello": 1, "howdy": 1, "hola": 1, "bonjour": 1, "konnichiwa": 1, "tag": 1, "guten": 1, "ola": 1, "about": 6, "school": 13, "the": 14, "tell": 6, "me": 7, "makes": 1, "what": 3, "unique": 1, "features": 1, "an": 1, "overview": 1, "give": 1, "of": 2, "apply": 1, "admission": 2, "for": 2, "i": 3, "how": 4, "can": 3, "process": 1, "application": 1, "procedure": 1, "extracurricular": 2, "activities": 2, "are": 2, "available": 2, "clubs": 1, "and": 2, "options": 2, "events": 3, "upcoming": 1, "soon": 1, "happening": 1, "any": 2, "what\'s": 1, "cafeteria": 2, "today": 1, "menu": 1, "lunch": 1, "offerings": 1, "contact": 3, "administration": 1, "details": 1, "office": 1, "library": 2, "services": 1, "books": 1, "sports": 2, "have": 1, "does": 1, "facilities": 3, "amenities": 1, "athletic": 1, "scholarship": 2, "opportunities": 1, "programs": 2, "aid": 1, "financial": 1, "in": 2, "technology": 2, "classrooms": 1, "classroom": 1, "interactive": 1, "learning": 1, "tour": 1, "tours": 1, "campus": 1, "visit": 1, "community": 2, "involved": 1, "engagement": 1, "outreach": 1, "philosophy": 2, "school\'s": 1, "educational": 1, "teaching": 1, "approach": 1, "education": 1, "inclusion": 1, "addressing": 1, "diversity": 2, "initiatives": 1, "environment": 1, "inclusive": 1}',
#  'index_docs': '{"15": 2, "16": 2, "6": 4, "8": 3, "37": 1, "38": 1, "39": 1, "40": 1, "41": 1, "42": 1, "44": 1, "43": 1, "45": 1, "5": 6, "2": 13, "1": 14, "4": 6, "3": 7, "46": 1, "9": 3, "47": 1, "48": 1, "50": 1, "51": 1, "49": 1, "17": 2, "52": 1, "19": 2, "18": 2, "11": 3, "7": 4, "10": 3, "53": 1, "54": 1, "55": 1, "20": 2, "21": 2, "22": 2, "23": 2, "56": 1, "24": 2, "25": 2, "12": 3, "57": 1, "59": 1, "58": 1, "26": 2, "60": 1, "27": 2, "62": 1, "61": 1, "63": 1, "64": 1, "13": 3, "65": 1, "66": 1, "67": 1, "28": 2, "68": 1, "69": 1, "29": 2, "71": 1, "70": 1, "14": 3, "72": 1, "73": 1, "30": 2, "74": 1, "31": 2, "76": 1, "75": 1, "33": 2, "32": 2, "77": 1, "78": 1, "79": 1, "80": 1, "81": 1, "82": 1, "84": 1, "83": 1, "34": 2, "85": 1, "86": 1, "87": 1, "35": 2, "88": 1, "89": 1, "90": 1, "91": 1, "92": 1, "94": 1, "93": 1, "36": 2, "95": 1, "97": 1, "96": 1}',
#  'index_word': '{"1": "the", "2": "school", "3": "me", "4": "tell", "5": "about", "6": "there", "7": "how", "8": "is", "9": "what", "10": "can", "11": "i", "12": "events", "13": "contact", "14": "facilities", "15": "hi", "16": "hey", "17": "of", "18": "for", "19": "admission", "20": "extracurricular", "21": "activities", "22": "are", "23": "available", "24": "and", "25": "options", "26": "any", "27": "cafeteria", "28": "library", "29": "sports", "30": "scholarship", "31": "programs", "32": "technology", "33": "in", "34": "community", "35": "philosophy", "36": "diversity", "37": "anyone", "38": "hello", "39": "howdy", "40": "hola", "41": "bonjour", "42": "konnichiwa", "43": "guten", "44": "tag", "45": "ola", "46": "makes", "47": "unique", "48": "features", "49": "give", "50": "an", "51": "overview", "52": "apply", "53": "process", "54": "application", "55": "procedure", "56": "clubs", "57": "upcoming", "58": "happening", "59": "soon", "60": "what\'s", "61": "menu", "62": "today", "63": "lunch", "64": "offerings", "65": "administration", "66": "details", "67": "office", "68": "services", "69": "books", "70": "does", "71": "have", "72": "amenities", "73": "athletic", "74": "opportunities", "75": "financial", "76": "aid", "77": "classrooms", "78": "classroom", "79": "interactive", "80": "learning", "81": "tour", "82": "tours", "83": "visit", "84": "campus", "85": "involved", "86": "engagement", "87": "outreach", "88": "school\'s", "89": "educational", "90": "teaching", "91": "approach", "92": "education", "93": "addressing", "94": "inclusion", "95": "initiatives", "96": "inclusive", "97": "environment"}',
#  'word_index': '{"the": 1, "school": 2, "me": 3, "tell": 4, "about": 5, "there": 6, "how": 7, "is": 8, "what": 9, "can": 10, "i": 11, "events": 12, "contact": 13, "facilities": 14, "hi": 15, "hey": 16, "of": 17, "for": 18, "admission": 19, "extracurricular": 20, "activities": 21, "are": 22, "available": 23, "and": 24, "options": 25, "any": 26, "cafeteria": 27, "library": 28, "sports": 29, "scholarship": 30, "programs": 31, "technology": 32, "in": 33, "community": 34, "philosophy": 35, "diversity": 36, "anyone": 37, "hello": 38, "howdy": 39, "hola": 40, "bonjour": 41, "konnichiwa": 42, "guten": 43, "tag": 44, "ola": 45, "makes": 46, "unique": 47, "features": 48, "give": 49, "an": 50, "overview": 51, "apply": 52, "process": 53, "application": 54, "procedure": 55, "clubs": 56, "upcoming": 57, "happening": 58, "soon": 59, "what\'s": 60, "menu": 61, "today": 62, "lunch": 63, "offerings": 64, "administration": 65, "details": 66, "office": 67, "services": 68, "books": 69, "does": 70, "have": 71, "amenities": 72, "athletic": 73, "opportunities": 74, "financial": 75, "aid": 76, "classrooms": 77, "classroom": 78, "interactive": 79, "learning": 80, "tour": 81, "tours": 82, "visit": 83, "campus": 84, "involved": 85, "engagement": 86, "outreach": 87, "school\'s": 88, "educational": 89, "teaching": 90, "approach": 91, "education": 92, "addressing": 93, "inclusion": 94, "initiatives": 95, "inclusive": 96, "environment": 97}'}

# %%
vocab_size = len(tokenizer.word_index)  
print('number of unique words = ', vocab_size)
# Out:
# number of unique words =  97

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

ptrn2seq = tokenizer.texts_to_sequences(df['patterns'])  # Mengonversi teks pola menjadi urutan angka
X = pad_sequences(ptrn2seq, padding='post')  # Melakukan padding terhadap urutan angka
print('X shape = ', X.shape)  # Menampilkan bentuk (shape) dari X

lbl_enc = LabelEncoder()  # Membuat objek LabelEncoder
y = lbl_enc.fit_transform(df['tag'])  # Mengonversi label kelas menjadi angka
print('y shape = ', y.shape)  # Menampilkan bentuk (shape) dari y
print('num of classes = ', len(np.unique(y)))  # Menampilkan jumlah kelas unik
# Out:
# X shape =  (55, 8)
# y shape =  (55,)
# num of classes =  15

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Embedding, LSTM, LayerNormalization, Dense, Dropout
from tensorflow.keras.utils import plot_model

model = Sequential()  # Membuat model Sequential

# Menambahkan lapisan-lapisan ke dalam model
model.add(Input(shape=(X.shape[1])))  # Lapisan input dengan bentuk sesuai dengan X
model.add(Embedding(input_dim=vocab_size+1, output_dim=100, mask_zero=True))  # Lapisan embedding dengan vocab_size + 1 sebagai input_dim
model.add(LSTM(32, return_sequences=True))  # Lapisan LSTM dengan 32 unit dan return_sequences=True
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(LSTM(32, return_sequences=True))  # Lapisan LSTM kedua dengan 32 unit dan return_sequences=True
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(LSTM(32))  # Lapisan LSTM ketiga dengan 32 unit
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(Dense(128, activation="relu"))  # Lapisan dense dengan 128 unit dan fungsi aktivasi ReLU
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(Dropout(0.2))  # Lapisan dropout dengan tingkat dropout 0.2
model.add(Dense(128, activation="relu"))  # Lapisan dense kedua dengan 128 unit dan fungsi aktivasi ReLU
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(Dropout(0.2))  # Lapisan dropout kedua dengan tingkat dropout 0.2
model.add(Dense(len(np.unique(y)), activation="softmax"))  # Lapisan dense terakhir dengan jumlah unit sesuai dengan jumlah kelas dan fungsi aktivasi softmax

model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=['accuracy'])  # Mengompilasi model dengan optimizer Adam, fungsi loss sparse_categorical_crossentropy, dan metrik akurasi

model.summary()  # Menampilkan ringkasan model
plot_model(model, show_shapes=True)  # Menampilkan struktur visual model
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 8, 100)            9800
#
#  lstm_24 (LSTM)              (None, 8, 32)             17024
#
#  layer_normalization_40 (La  (None, 8, 32)             64
#  yerNormalization)
#
#  lstm_25 (LSTM)              (None, 8, 32)             8320
#
#  layer_normalization_41 (La  (None, 8, 32)             64
#  yerNormalization)
#
#  lstm_26 (LSTM)              (None, 32)                8320
#
#  layer_normalization_42 (La  (None, 32)                64
#  yerNormalization)
#
#  dense_24 (Dense)            (None, 128)               4224
#
#  layer_normalization_43 (La  (None, 128)               256
#  yerNormalization)
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_25 (Dense)            (None, 128)               16512
#
#  layer_normalization_44 (La  (None, 128)               256
#  yerNormalization)
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_26 (Dense)            (None, 15)                1935
#
# =================================================================
# Total params: 66839 (261.09 KB)
# Trainable params: 66839 (261.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_history = model.fit(x=X,  # Data input X
                          y=y,  # Data output y
                          batch_size=10,  # Ukuran batch yang digunakan dalam setiap iterasi
                          callbacks=[tensorflow.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)],  # Menggunakan EarlyStopping untuk menghentikan pelatihan jika akurasi tidak meningkat setelah 3 epoch
                          epochs=50)  # Jumlah epoch (iterasi) pelatihan
# Out:
# Epoch 1/50
# 6/6 [==============================] - 12s 11ms/step - loss: 3.7209 - accuracy: 0.0364
# Epoch 2/50
# 6/6 [==============================] - 0s 11ms/step - loss: 2.2694 - accuracy: 0.3455
# Epoch 3/50
# 6/6 [==============================] - 0s 11ms/step - loss: 1.5464 - accuracy: 0.4727
# Epoch 4/50
# 6/6 [==============================] - 0s 11ms/step - loss: 1.0981 - accuracy: 0.6182
# Epoch 5/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.9773 - accuracy: 0.7818
# Epoch 6/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.8739 - accuracy: 0.7455
# Epoch 7/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5054 - accuracy: 0.8727
# Epoch 8/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5912 - accuracy: 0.8364
# Epoch 9/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4136 - accuracy: 0.9091
# Epoch 10/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3439 - accuracy: 0.9273
# Epoch 11/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3484 - accuracy: 0.9455
# Epoch 12/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2867 - accuracy: 0.9273
# Epoch 13/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2057 - accuracy: 0.9818
# Epoch 14/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1573 - accuracy: 0.9818
# Epoch 15/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1931 - accuracy: 0.9636
# Epoch 16/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1711 - accuracy: 0.9455

# %%
import re
import random

def inputan_user(pattern):
    text = []
    txt = re.sub('[^a-zA-Z\']', ' ', pattern)  
    txt = txt.lower()  
    txt = txt.split()  
    txt = " ".join(txt)  
    text.append(txt)  

    # Tokenize and pad the input pattern
    x_test = tokenizer.texts_to_sequences(text)  
    x_test = pad_sequences(x_test, padding='post', maxlen=8)  # Keep this consistent with the expected input length

    # Make prediction using the model
    y_pred = loaded_model_school.predict(x_test)  
    y_pred = y_pred.argmax()  
    tag = lbl_enc.inverse_transform([y_pred])[0]  
    responses = df[df['tag'] == tag]['responses'].values[0]  

    # Display user input and bot response
    print("User: {}".format(pattern))
    print(" BOT : {}".format(random.choice(responses)))

# %%
# Test the function with an example
inputan_user("Hello")
# Out:
# 1/1 [==============================] - 0s 28ms/step
# User: Hello
#  BOT : Hello there. How can I help you?

# %%
inputan_user("Tell me about the school")
# Out:
# 1/1 [==============================] - 0s 27ms/step
# User: Tell me about the school
#  BOT : Our school library provides a quiet and comfortable space for studying. We have a diverse collection of books covering various genres.

# %%
inputan_user("How can I apply for admission?")
# Out:
# 1/1 [==============================] - 0s 22ms/step
# User: How can I apply for admission?
#  BOT : To apply for admission, you can visit our school website and follow the online application process. If you have specific questions, feel free to ask.

# %%
inputan_user("What extracurricular activities are available?")
# Out:
# 1/1 [==============================] - 0s 23ms/step
# User: What extracurricular activities are available?
#  BOT : We offer a wide range of extracurricular activities, including sports, arts, and science clubs. Students can explore their interests and passions.

# %%
inputan_user("Tell me about upcoming events")
# Out:
# 1/1 [==============================] - 0s 22ms/step
# User: Tell me about upcoming events
#  BOT : Stay tuned for our upcoming events! We regularly organize workshops, competitions, and community gatherings to enrich the student experience.

# %%
inputan_user("What's the cafeteria menu for today?")
# Out:
# 1/1 [==============================] - 0s 38ms/step
# User: What's the cafeteria menu for today?
#  BOT : Our cafeteria serves a variety of healthy and delicious options. You can check the daily menu on our school website or at the cafeteria notice board.

# %%
# Save the Tokenizer
with open('tokenizer.pkl', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# Save the Label Encoder
with open('label_encoder.pkl', 'wb') as handle:
    pickle.dump(lbl_enc, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
model.save("my_model.keras")

# %%
from tensorflow.keras.models import load_model

model_path_school = 'my_model.keras'  # Update with the correct path
loaded_model_school = load_model(model_path_school)

# Debugging: Check the input shape of the loaded model
print("Loaded Model Input Shape:", loaded_model_school.input_shape)
# Out:
# Loaded Model Input Shape: (None, 8)
